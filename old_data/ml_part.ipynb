# %%
import tensorflow as tf
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv("sensor_data.csv")

# %%
# Out:
# 0       76.9
# 1       31.8
# 2       75.7
# 3       88.3
# 4       57.2
#        ...
# 179     58.5
# 180     30.9
# 181     51.6
# 182    100.0
# 183     68.0
# Name: Temperature(°C), Length: 184, dtype: float64

# %%
scaler = MinMaxScaler()
scaler.fit(data)
scaler.data_max_
pre_prcs_data = scaler.transform(data)

# %%
pre_prcs_data[:,:-1]
# Out:
# array([[0.38542381, 0.71125   ],
#        [0.01713502, 0.1475    ],
#        [0.38542381, 0.69625   ],
#        [0.7349783 , 0.85375   ],
#        [0.69842358, 0.465     ],
#        [0.8560658 , 0.0525    ],
#        [0.57276674, 0.2925    ],
#        [0.34886909, 0.7675    ],
#        [0.04272333, 0.95375   ],
#        [0.1660955 , 0.485     ],
#        [0.25519762, 0.22875   ],
#        [0.17980352, 0.1525    ],
#        [0.04135252, 0.575     ],
#        [0.78067169, 0.3225    ],
#        [0.97943797, 0.3375    ],
#        [0.49051862, 0.24875   ],
#        [1.        , 0.38      ],
#        [0.25291295, 0.40375   ],
#        [0.55220471, 0.37125   ],
#        [0.73040896, 0.18      ],
#        [0.01302262, 0.83375   ],
#        [0.27575965, 0.        ],
#        [0.07927804, 0.28125   ],
#        [0.12497144, 0.35875   ],
#        [0.97943797, 0.0475    ],
#        [0.3785698 , 0.455     ],
#        [0.79437971, 0.585     ],
#        [0.12497144, 0.00375   ],
# ...

# %%
# data.iloc[:, -1] = data.iloc[:, -1]/100

# %%
data
# Out:
#      Humidity(%)  Temperature(°C)  WaterFlow(%)
# 0          25.00             76.9         0.674
# 1           8.88             31.8         0.000
# 2          25.00             75.7         0.661
# 3          40.30             88.3         0.000
# 4          38.70             57.2         0.000
# ..           ...              ...           ...
# 179        48.60             58.5         0.000
# 180        14.50             30.9         0.000
# 181        35.40             51.6         0.000
# 182        23.90            100.0         0.961
# 183        36.00             68.0         0.000
#
# [184 rows x 3 columns]

# %%
x = pre_prcs_data[:,:-1]
y = pre_prcs_data[:, -1]
x_trn, x_tst, y_trn, y_tst = train_test_split(x, y, test_size = 0.3)

# %%
x_trn
# Out:
# array([[0.3785698 , 0.66875   ],
#        [0.20493489, 0.76125   ],
#        [0.63216815, 0.3875    ],
#        [0.72127028, 0.21375   ],
#        [0.92460589, 0.67875   ],
#        [0.43340187, 0.535     ],
#        [0.9017592 , 0.44875   ],
#        [0.01507882, 0.14      ],
#        [0.38542381, 0.69625   ],
#        [0.79894905, 0.685     ],
#        [0.92917523, 0.5625    ],
#        [0.28946767, 0.19125   ],
#        [0.7349783 , 0.85375   ],
#        [0.63445282, 0.95      ],
#        [0.36486178, 0.9025    ],
#        [0.08156271, 0.505     ],
#        [0.35115376, 0.03      ],
#        [0.67557688, 0.88875   ],
#        [0.46995659, 0.53125   ],
#        [0.38542381, 0.71125   ],
#        [0.41512451, 0.10375   ],
#        [0.80123372, 0.265     ],
#        [0.73040896, 0.18      ],
#        [0.88576651, 0.545     ],
#        [0.05643135, 0.26875   ],
#        [0.39456249, 0.1475    ],
#        [0.78067169, 0.1575    ],
#        [0.12497144, 0.35875   ],
# ...

# %%
def ml_model():
    model = Sequential()
    model.add(Dense(64, input_shape=(2,), kernel_initializer='normal', activation='relu'))
    model.add(Dense(128, kernel_initializer='normal', activation='relu'))
    model.add(Dense(128, kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, kernel_initializer='normal'))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

estimator = KerasRegressor(model=ml_model, epochs=100, batch_size=5, verbose=0)
kfold = KFold(n_splits=5)
results = cross_val_score(estimator, x_trn, y_trn, cv=kfold, scoring='neg_mean_squared_error')
print("Baseline: %.2f (%.2f) MSE" % (results.mean(), results.std()))

# %%
model = Sequential()
model.add(Dense(64, input_shape=(2,), kernel_initializer='normal', activation='relu'))
model.add(Dense(128, kernel_initializer='normal', activation='relu'))
model.add(Dense(128, kernel_initializer='normal', activation='relu'))
model.add(Dense(1, kernel_initializer='normal'))
model.compile(loss='mean_squared_error', optimizer='adam')
